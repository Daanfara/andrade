# %% [markdown]
# <a href="https://colab.research.google.com/github/Daanfara/andrade/blob/main/pandas_prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
datos='https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'

# %%
datos=pd.read_csv(datos)
datos.head(5)
# Out:
#    station_id       stationname        date daytype  rides
# 0       41280    Jefferson Park  12/22/2017       W   6104
# 1       41000  Cermak-Chinatown  12/18/2017       W   3636
# 2       40280      Central-Lake  12/02/2017       A   1270
# 3       40140   Dempster-Skokie  12/19/2017       W   1759
# 4       40690          Dempster  12/03/2017       U    499

# %%
datos.shape
# Out:
# (1145586, 5)

# %%
datos.columns
# Out:
# Index(['station_id', 'stationname', 'date', 'daytype', 'rides'], dtype='object')

# %%
datos.describe
# Out:
# <bound method NDFrame.describe of          station_id        stationname        date daytype  rides
# 0             41280     Jefferson Park  12/22/2017       W   6104
# 1             41000   Cermak-Chinatown  12/18/2017       W   3636
# 2             40280       Central-Lake  12/02/2017       A   1270
# 3             40140    Dempster-Skokie  12/19/2017       W   1759
# 4             40690           Dempster  12/03/2017       U    499
# ...             ...                ...         ...     ...    ...
# 1145581       41700  Washington/Wabash  12/27/2022       W   3991
# 1145582       41700  Washington/Wabash  12/28/2022       W   4100
# 1145583       41700  Washington/Wabash  12/29/2022       W   4741
# 1145584       41700  Washington/Wabash  12/30/2022       W   4664
# 1145585       41700  Washington/Wabash  12/31/2022       A   2774
#
# [1145586 rows x 5 columns]>

# %%
datos.tail(5)
# Out:
#          station_id        stationname        date daytype  rides
# 1145581       41700  Washington/Wabash  12/27/2022       W   3991
# 1145582       41700  Washington/Wabash  12/28/2022       W   4100
# 1145583       41700  Washington/Wabash  12/29/2022       W   4741
# 1145584       41700  Washington/Wabash  12/30/2022       W   4664
# 1145585       41700  Washington/Wabash  12/31/2022       A   2774

# %%
datos.dtypes
# Out:
# station_id      int64
# stationname    object
# date           object
# daytype        object
# rides           int64
# dtype: object

# %%
print(type(datos))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
datos.describe()
# Out:
#          station_id         rides
# count  1.145586e+06  1.145586e+06
# mean   4.076649e+04  3.056635e+03
# std    4.490665e+02  3.118576e+03
# min    4.001000e+04  0.000000e+00
# 25%    4.037000e+04  9.630000e+02
# 50%    4.076000e+04  2.004000e+03
# 75%    4.115000e+04  4.025000e+03
# max    4.170000e+04  3.632300e+04

# %%
print(datos['rides'].min())
print(datos['rides'].max())
# Out:
# 0
# 36323

# %%
filter=datos['rides']==datos['rides'].max()

# %%
mask=datos['rides']=0
print(datos['stationname']==mask)
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1145581    False
# 1145582    False
# 1145583    False
# 1145584    False
# 1145585    False
# Name: stationname, Length: 1145586, dtype: bool

# %%
datos['date']=pd.to_datetime(datos['date'])

# %%
datos.set_index('date', inplace=True)

# Print the DataFrame with the new DateTime index
print(datos)
# Out:
#             station_id        stationname daytype  rides
# date
# 2017-12-22       41280     Jefferson Park       W      0
# 2017-12-18       41000   Cermak-Chinatown       W      0
# 2017-12-02       40280       Central-Lake       A      0
# 2017-12-19       40140    Dempster-Skokie       W      0
# 2017-12-03       40690           Dempster       U      0
# ...                ...                ...     ...    ...
# 2022-12-27       41700  Washington/Wabash       W      0
# 2022-12-28       41700  Washington/Wabash       W      0
# 2022-12-29       41700  Washington/Wabash       W      0
# 2022-12-30       41700  Washington/Wabash       W      0
# 2022-12-31       41700  Washington/Wabash       A      0
#
# [1145586 rows x 4 columns]
